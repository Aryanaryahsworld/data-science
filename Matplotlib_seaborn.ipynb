# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# line plot

# %%
days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
temperatures = [21, 23, 20, 22, 24, 19, 21]  # Changed temperature values

plt.plot(days, temperatures, color='blue', linestyle='-', marker='o')
plt.xlabel('Days of the Week')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Trends Over a Week')
plt.grid(True)
plt.show()

# %% [markdown]
# scatter plot

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x, y)
plt.title('Random Data Distribution')
plt.show()
height = np.random.randint(150, 200, 50)  # Heights in cm
weight = np.random.randint(50, 100, 50)   # Weights in kg

plt.scatter(height, weight)
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.title('Height vs. Weight Distribution')
plt.show()

# %% [markdown]
# Bar Plot

# %%
companies = ['Company A', 'Company B', 'Company C']
shares = [20, 35, 40]
plt.bar(companies, shares)
plt.xlabel('Company')
plt.ylabel('Shares')
plt.title('Company Shares')
plt.show()
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [200, 180, 220, 210, 230]  # Sales values in units

plt.bar(months, sales, color='green')
plt.xlabel('Month')
plt.ylabel('Sales (Units)')
plt.title('Monthly Sales Data')
plt.show()

# %%
grades = np.random.randint(40, 100, 100)
plt.hist(grades, bins=6)
plt.xlabel('Grades')
plt.ylabel('Number of Students')
plt.title('Distribution of Student Grades')
plt.show()

scores = np.random.randint(0, 100, 100)  # Generating random scores
plt.hist(scores, bins=10, color='orange', edgecolor='black')
plt.xlabel('Scores')
plt.ylabel('Number of Students')
plt.title('Exam Score Distribution')
plt.show()

# %%
market_shares = [30, 20, 25, 25]
labels = ['Company A', 'Company B', 'Company C', 'Company D']
plt.pie(market_shares, labels=labels, autopct='%1.1f%%')
plt.title('Market Shares')
plt.show()

shares = [25, 35, 15, 25]  # Market share percentages
products = ['Product A', 'Product B', 'Product C', 'Product D']

plt.pie(shares, labels=products, autopct='%1.1f%%', startangle=140)
plt.title('Market Share Analysis')
plt.show()

# %%
scores = np.random.randint(0, 100, 100)
plt.boxplot(scores)
plt.title('Test Score Distribution')
plt.show()

ratings = np.random.uniform(1, 5, 100)  # Ratings between 1 and 5

plt.boxplot(ratings)
plt.ylabel('Satisfaction Rating')
plt.title('Employee Satisfaction Ratings')
plt.grid(True)
plt.show()

# %% [markdown]
# Matplotlib using Seaborn

# %%
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#Bar plot used in counting the number of passengers
sns.countplot(x='class', data=titanic)
plt.title('Passenger Class Count')
plt.show()

# %%
#Age Distribution
sns.histplot(titanic['age'], kde=False, bins=10)
plt.title('Age Distribution of Passengers')
plt.show()

# %%
#Gender distribution
gender_counts = titanic['sex'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
sns.boxplot(y='fare', data=titanic)
plt.title('Fare Distribution')
plt.show()
#Fare distribution box plot

# %%
#age vs fare using scatter plot
sns.scatterplot(x='age', y='fare', data=titanic)
plt.title('Age vs. Fare')
plt.show()

# %%
#Multivariate analysis Pair plot
sns.pairplot(titanic[['age', 'fare', 'class']], hue='class')
plt.show()

# %%
sns.violinplot(x='class', y='age', data=titanic)
plt.title('Age Distribution by Passenger Class')
plt.show()
# Violet plot age distribution by class

# %%
sns.stripplot(x='class', y='age', hue='sex', data=titanic)
plt.title('Class vs. Age with Gender')
plt.show()
#strip plot age distribution vs class

# %% [markdown]
# # **Advanced approach
# **

# %%
#survival rate by class gender hue
sns.catplot(x='class', hue='sex', col='survived', data=titanic, kind='count')
plt.subplots_adjust(top=0.8)
plt.suptitle('Survival Rate by Class and Gender')
plt.show()

# %%
#Kernel Density estimation for age
sns.histplot(titanic['age'], kde=True, bins=20, color='green')
plt.title('Age Distribution with Kernel Density Estimation')
plt.show()

# %%
#fair distribution by class gender hue using violin plot
sns.violinplot(x='class', y='fare', hue='sex', split=True, data=titanic)
plt.title('Fare Distribution by Class and Gender')
plt.show()

# %%
#joinjt plot - age and fare with regression line
sns.jointplot(x='age', y='fare', data=titanic, kind='reg', color='purple')
plt.suptitle('Age vs. Fare with Regression Line', y=1.02)
plt.show()

# %%
#swarm plot combined with violin plot age by class
plt.figure(figsize=(10, 6))
sns.violinplot(x='class', y='age', data=titanic, inner=None, color='lightgray')
sns.swarmplot(x='class', y='age', data=titanic, hue='sex')
plt.title('Age Distribution by Class with Swarm Plot Overlay')
plt.show()

# %%
#pair plot advanved multivariate analysis
sns.pairplot(titanic.dropna(), vars=['age', 'fare', 'pclass'], hue='sex', diag_kind='kde', palette='Dark2')
plt.suptitle('Advanced Multivariate Analysis: Age, Fare, and Class', size=16, y=1.02)
plt.show()

# %%
#heat map corelation matrix
corr = titanic.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlation Matrix')
plt.show()
# Out:
# <ipython-input-60-74d21f372fe6>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = titanic.corr()

# %%
#facet grid mutliple histograms for age by class by gender
g = sns.FacetGrid(titanic, col='class', row='sex')
g.map(sns.histplot, 'age', bins=15, kde=False)
g.add_legend()
plt.show()
